# %% [markdown]
# Discrete Math 2 - Lecture 1 Answers

# %% [markdown]
# Name: Nicole Grace L. Joligon
#
# Program and Year: BSCS- 1

# %% [markdown]
# $\textbf{Assignment}$
# Instructions:
# - Use latex.
# - Write your latex in jupyter notebook.
# - Push your answer to your github account.
# - Deadline is 2 weeks before finals.
# - Fail to submit 2 weeks before finals is an automatic 5.0 for this assignment.
# - Each problem is 25 points.
#
# 1. Recall the definition of a rational number, denoted as $\mathbb{Q}$. Prove that the Euler's number $e = \Sigma_{k=0}^\infty \frac{1}{k!} \notin \mathbb{Q}$. A factorial is defined as $k! = (k)(k-1)(k-2)(k-3)..., \forall k \in \mathbb{Z}^+$, note that $0! = 1$. Furthermore, a sum notation $\Sigma_{k=0}^\infty k = 0+ 1 + 2 + 3 +....+...$
#
# Step 1: Let's start by supposing that $e$ can be expressed as a fraction $\frac{p}{q}$ where $p$ and $q$ are integers with no common factors except 1, and $q \neq 0$.
#
# Step 2: Remember that $e$ is defined as the sum of an infinite series:
#
# $ e = \Sigma_{k=0}^\infty \frac{1}{k!}$
# ​
#
# Step 3: Let's examine the partial sums of this series. We'll denote the $n$th partial sum as $S_n$:
#
# $S_n = \Sigma_{k=0}^\infty \frac{1}{k!}$
#
# Step 4: We define $e$ as the limit of these partial sums as $n$ tends to infinity:
#
# $e = \lim_{n \to \infty} S_n$
#
# Step 5: If $e$ is rational, then the partial sums $S_n$ must also tend towards a rational number as $n$ increases infinitely.
#
# Step 6: Note that each term in the series $\frac{1}{k!}$ is positive, so each partial sum $S_n$ is increasing.
#
# Step 7: Let's consider the factorial terms $k!$. For any $k \geq 1$, $k!$ is always greater than $k$, which means $\frac{1}{k!}$ is less than $\frac{1}{k}$.
#
# Step 8: Recognize that the series $\sum_{k=0}^\infty \frac{1}{k}$ diverges (known as the harmonic series).
#
# Step 9: Since $\frac{1}{k!}$ is smaller than $\frac{1}{k}$, we conclude that the series $\sum_{k=0}^\infty \frac{1}{k!}$ converges.
#
# Step 10: If the partial sums $S_n$ converge to a rational number, they must be bounded.
#
# Step 11: However, the convergence of $\sum_{k=0}^\infty \frac{1}{k!}$ contradicts the unboundedness of the harmonic series.
#
# $\textbf{Conclusion}$: Hence, assuming $e$ is rational leads to a contradiction. Thus, we conclude that $e$ is not rational, i.e., $e \notin \mathbb{Q}$.
#
# --------------------------------------------------------------------------------------------------

# %% [markdown]
# 2. Prove Minkowski's Inequality for sums, $\forall \ p>1, (a_k, b_k)>0$:
#
# \begin{gather}
# \begin{bmatrix}
# \Sigma_{k=1}^n |a_k + b_k|^p
# \end{bmatrix}^\frac{1}{p}
# \leq
# \begin{bmatrix}
# \Sigma_{k=1}^n |a_k|^p
# \end{bmatrix}^\frac{1}{p}
#
# \begin{bmatrix}
# \Sigma_{k=1}^n |b_k|^p
# \end{bmatrix}^\frac{1}{p}
# \end{gather}
#
# Let's demonstrate Minkowski's Inequality for sums directly using the Triangle Inequality theorem:
#
# $$
# |a + b| \leq |a| + |b|
# $$
#
# Step 1: We begin by exponentiating both sides of the inequality to the power of
# p:
#
# $$
# |a + b|^{p} \leq |a|^{p} + |b|^{p}
# $$
#
# Step 2: Introduce summation notation for all k from 1 to n:
#
# $$
# \sum_{k = 1}^{n} |a_k + b_k|^{p} \leq \sum_{k=1}^{n} |a_k|^{p} + \sum_{k =1 }^{n} |b_k|^{p}
# $$
#
# Step 3: Raise to 1 over p by property of absolute value
#
# $$
# [\sum_{k = 1}^{n}|a_k + b_k|^{p}]^{\frac{1}{p}} \leq [\sum_{k = 1}^{n} |a_k|^{p}]^{\frac{1}{p}} + [\sum_{k = 1}^{n}|b_k|^{p}]^{\frac{1}{p}}
# $$
#
# Hence, we have proved Minkowski's Inequality for sums by utilizing the Triangle Inequality theorem.
#
# -------------------------------

# %% [markdown]
# 3. Prove the triangle inequality $|x+y| \leq |x| + |y|, \forall (x,y) \in \mathbb{R}$
#
# Step 1: Absolute value definition
#
# - Definition
# \begin{gather}
# {|x| = }
# \begin{cases}
# x,&{x \geq 0}\\ -x,&{x < 0}
# \end{cases}
# \end{gather}
#
# - We need to address 4 cases:
#
# \begin{gather}
# \text{Case 1: }{x \geq 0, y \geq 0} \\
# \text{Case 2: }{x < 0, y < 0} \\
# \text{Case 3: }{x \geq 0, y < 0} \\
# \text{Case 4: }{x < 0, y \geq 0} \\
# \end{gather}
#
# Case 1: $x \geq 0, y \geq 0$
#
# - Assume $|x + y| = x + y$, and $|x| = x, |y| = y$
# - Substitution:
# \begin{gather}
# |x + y| = x + y = |x| + |y|
# \end{gather}
#
# Case 2: $x < 0, y < 0$
#
# - Assume $|x + y| = -(x + y)$, and $|x| = -x, |y| = -y$
# - Substitution:
# \begin{gather}
# |x + y| = -(x + y) = -x + (-y) = |x| + |y|
# \end{gather}
#
# Case 3: $x \geq 0, y < 0$
#
# - Assume $|x| = x, |y| = -y$
# - Substitution:
# \begin{gather}
# |x + y| \leq x - y
# \end{gather}
# - Since, $x$  is non-negative and $y$ is negative, $x - y$ could be either positive or negative. So, let's consider both possibilities:
#
# For $x + y \geq 0$:
# \begin{gather}
# x + y \leq x - y \\
# y \leq -y
# \end{gather}
#
# For $x + y < 0$:
# \begin{gather}
# -(x + y) \leq x - y \\
# -x - y \leq x - y \\
# -x \leq x
# \end{gather}
#
# Case 4: $x < 0, y \geq 0$
#
# - Assume $|x| = -x, |y| = y$
# - Substitution:
# \begin{gather}
# |x + y| \leq -x + y
# \end{gather}
# - Solve for sub-cases of $|x + y|$:
# \begin{gather}
# x + y, x + y \geq 0 \\
# -(x + y), x + y < 0 \\
# \end{gather}
#
# For $x + y \geq 0$:
# \begin{gather}
# x + y \leq -x + y \\
# x \leq -x
# \end{gather}
#
# For $x + y < 0$:
# \begin{gather}
# -(x + y) \leq -x + y \\
# -x - y \leq -x + y \\
# -y \leq y
# \end{gather}
#
# $\textbf{Conclusion}$: Hence, in all cases, $|x+y| \leq |x| + |y| \in \mathbb{R} $
#
#
#
# --------

# %% [markdown]
# 4. Prove Sedrakayan's Lemma $\forall u_i, v_i \in \mathbb{R}^+$:
# \begin{gather}
# \frac{(\Sigma_{i=1}^n u_i)^2}{\Sigma_{i=1}^n v_i}
# \leq
# \Sigma_{i=1}^n \frac{(u_i)^2}{v_i}
# \end{gather}
#
#
# recalling the Cauchy-Schwarz inequality for Real Numbers...
#
# $$
# (\sum_{i=1}^{n}a_i b_i)^{2} \leq (\sum_{i=1}^{n}a_i^{2})(\sum_{i=1}^{n}b_i^{2})
# $$
#
# lets substitute $a_i = u_i$ and $b_i = \sqrt{v_i}$
#
# $$
# (\sum_{i=1}^{n}u_i \sqrt{v_i})^{2} \leq (\sum_{i=1}^{n}u_i^{2})(\sum_{i=1}^{n}\sqrt{v_i}^{2})
# $$
#
# Considering the square root of even integers, let's substitute $u_i = \sqrt{2a_i}, \sqrt{v_i} = \sqrt{2b_i}$
#
# $$
# (\sum_{i=1}^{n}\sqrt{2a_i}\sqrt{2b_i})^{2} \leq (\sum_{i=1}^{n}[\sqrt{2a_i}]^{2})(\sum_{i=1}^{n}[\sqrt{2b_i}]^{2})
# $$
#
# simplify
#
# $$
# 4\sum_{i=1}^{n}a_ib_i \leq 4\sum_{i=1}^{n}a_i\sum_{i=1}^{n}b_i
# $$
#
# divide both sides by... $4\sum_{i=1}^{n}b_i$
#
# $$
# \frac{4\sum_{i=1}^{n}a_ib_i \leq 4\sum_{i=1}^{n}a_i\sum_{i=1}^{n}b_i}{4\sum_{i=1}^{n}b_i}
# $$
#
# $$
# 4(\frac{1}{4} )\space [\sum_{i=1}^{n}a_ib_i (\frac{1}{[\sum_{i=1}^{n}b_i]})] \leq 4(\frac{1}{4})\space \sum_{i=1}^{n}a_i(\frac{1}{[\sum_{i=1}^{n}b_i]})\space\space \sum_{i=1}^{n}b_i (\frac{1}{[\sum_{i=1}^{n}b_i]})
# $$
#
# $$
# \frac{\sum_{i=1}^{n}a_i}{\sum_{i=1}^{n}b_i} \leq \sum_{i=1}^{n}\frac{a_i}{b_i}
# $$
#
# Recall $u_i = \sqrt{2a_i}, v_i = \sqrt{2b_i}$
#
# modify the equality to get $a$ and $b$
#
# $$
# u_i = \sqrt{2a_i}
# $$
# $$
# a = (\frac{u_i^{2}}{2})
# $$
#
# $$
# \sqrt{v_i} = \sqrt{2b_i}
# $$
# $$
# b = (\frac{\sqrt{v_i}^{2}}{2})
# $$
#
# Substitue and square the numerator to get Sedrakayan's Lemma
#
# $$
# \frac{\sum_{i=1}^{n}\frac{u_i^{2}}{2}}{\sum_{i=1}^{n}\frac{\sqrt{v_i}^{2}}{2}} \leq \sum_{i=1}^{n}\frac{\frac{u_i^{2}}{2}}{\frac{\sqrt{v_i}^{2}}{2}}
# $$
#
# $$
# \frac{(\sum_{i=1}^{n}u_i)^{2}}{\sum_{i=1}^{n}v_i} \leq \sum_{i=1}^{n}\frac{u_i^{2}}{v_i}
# $$
#
# THence, Sedrakyan's Lemma holds true for $ u_i $ and $ v_i $ being square roots of even integers.
